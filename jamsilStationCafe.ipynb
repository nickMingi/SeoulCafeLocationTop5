# %%
import pandas as pd

# 데이터프레임 읽기
data = pd.read_csv("소상공인시장진흥공단_상가(상권)정보_서울_202312.csv")

# 데이터프레임의 첫 몇 개 행 출력
print(data.head())

# 각 열의 데이터 유형 확인
print(data.dtypes)

# 혼합된 데이터 유형이 있는 열 확인
mixed_columns = data.columns[data.applymap(type).eq(str).any()]
print("Mixed type columns:", mixed_columns)
# Out:
# C:\Users\mjmok\AppData\Local\Temp\ipykernel_92016\1191192376.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("소상공인시장진흥공단_상가(상권)정보_서울_202312.csv")
#                  상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220805430767     토끼정  NaN        I2       음식      I201
# 1  MA010120220805430763     카페숲  NaN        I2       음식      I212
# 2  MA010120220805430969     다이앤  NaN        G2       소매      G209
# 3  MA010120220805431023    숯불에닭  NaN        I2       음식      I201
# 4  MA010120220805431191  맑은에스테틱  NaN        S2    수리·개인      S208
#
#       상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# 0           한식    I20101       백반/한정식   I56111  ...
# 1        비알코올     I21201           카페   I56221  ...
# 2  섬유·의복·신발 소매    G20902    여성 의류 소매업   G47412  ...
# 3           한식    I20110  닭/오리고기 구이/찜   I56111  ...
# 4      욕탕·신체관리    S20802       마사지/안마   S96122  ...
#
#                       건물관리번호     건물명                  도로명주소   구우편번호 신우편번호  \
# 0  1150010500107740012000001   마커스빌딩      서울특별시 강서구 마곡동로 55  157805  7802
# 1  1154510300109290010016890     NaN  서울특별시 금천구 시흥대로40길 129  153860  8647
# 2  1114016200107750000009546  제일평화시장        서울특별시 중구 마장로 13  100837  4567
# 3  1147010300109710004007555     NaN       서울특별시 양천구 지양로 60  158846  8040
# 4  1121510500100480053015378     NaN    서울특별시 광진구 뚝섬로32길 33  143843  5085
#
#    동정보 층정보  호정보          경도         위도
# 0  NaN   2  NaN  126.833022  37.560053
# 1  NaN   1  NaN  126.909939  37.446689
# 2  NaN   1  NaN  127.011381  37.568503
# 3  NaN   1  NaN  126.834524  37.520990
# 4  NaN   1  NaN  127.066814  37.534047
#
# [5 rows x 39 columns]
# 상가업소번호        object
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드           int64
# 시도명           object
# 시군구코드          int64
# 시군구명          object
# 행정동코드          int64
# 행정동명          object
# 법정동코드          int64
# 법정동명          object
# 지번코드           int64
# 대지구분코드         int64
# 대지구분명         object
# 지번본번지          int64
# 지번부번지        float64
# 지번주소          object
# 도로명코드          int64
# 도로명           object
# 건물본번지        float64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호          int64
# 신우편번호          int64
# 동정보          float64
# 층정보           object
# 호정보          float64
# 경도           float64
# 위도           float64
# dtype: object
# C:\Users\mjmok\AppData\Local\Temp\ipykernel_92016\1191192376.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mixed_columns = data.columns[data.applymap(type).eq(str).any()]
# Mixed type columns: Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도명',
#        '시군구명', '행정동명', '법정동명', '대지구분명', '지번주소', '도로명', '건물관리번호', '건물명',
#        '도로명주소', '층정보'],
#       dtype='object')

# %%
import folium
import pandas as pd
from geopy.distance import geodesic # 두 지점 간의 거리 계산

jamsil = folium.Map(location = [37.5131, 127.1006], zoom_start = 10) # zoom_start : 지도 초기 확대 수준
data = pd.read_csv("소상공인시장진흥공단_상가(상권)정보_서울_202312.csv")

# 잠실역 중심 지도
map = folium.Map(location = [37.5131, 127.1006], zoom_start = 10)

# 원을 그릴 위치의 위도와 경도를 설정
circle_lat_lon = [37.5131, 127.1006]

# folium.Circle() 메소드로 원 생성
folium.Circle(
    location = circle_lat_lon,
    radius = 200,  # 원의 반지름 (미터 단위)
    color = 'crimson',
    fill = True, # 테두리
    fill_color = 'crimson'
).add_to(map)

# 데이터프레임에서 원 안에 있는 위치 데이터를 추출합니다
locations_inside_circle = []
for index, row in data.iterrows():
    location = (row['위도'], row['경도'])
    if geodesic(location, circle_lat_lon).meters <= 200:  # 10000미터 이내에 있는지 확인
        locations_inside_circle.append(row['상가업소번호'])

print("원 안에 있는 장소:", locations_inside_circle)
# Out:
# C:\Users\mjmok\AppData\Local\Temp\ipykernel_92016\3962114898.py:6: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("소상공인시장진흥공단_상가(상권)정보_서울_202312.csv")
# 원 안에 있는 장소: ['MA010120220805950524', 'MA010120220806392932', 'MA010120220807025947', 'MA010120220808101819', 'MA010120220808173275', 'MA010120220808271627', 'MA010120220808564268', 'MA010120220808840852', 'MA010120220809834017', 'MA010120220810058792', 'MA010120220809994578', 'MA010120220810353892', 'MA010120220810430936', 'MA010120220810404175', 'MA010120220811125792', 'MA010120220811819009', 'MA010120220811966188', 'MA010120220812321289', 'MA010120220812300367', 'MA010120220812617666', 'MA010120220812625911', 'MA010120220813104580', 'MA010120220813457813', 'MA010120220813654422', 'MA010120220813830187', 'MA010120220813812383', 'MA010120220813943136', 'MA010120220814384814', 'MA010120220800073573', 'MA010120220800274766', 'MA010120220800337545', 'MA010120220800404129', 'MA010120220800367902', 'MA010120220801034954', 'MA010120220801038035', 'MA010120220800956325', 'MA010120220801909845', 'MA010120220802174691', 'MA010120220802513681', 'MA010120220803101675', 'MA010120220803234345', 'MA010120220803177156', 'MA010120220803372183', 'MA010120220803500202', 'MA010120220803665772', 'MA010120220803587589', 'MA010120220803563747', 'MA010120220804250444', 'MA010120220804256375', 'MA010120220804273509', 'MA010120220804294782', 'MA010120220804294647', 'MA010120220804294996', 'MA010120220804272663', 'MA010120220804274902', 'MA010120220804275332', 'MA010120220804184760', 'MA010120220804361949', 'MA010120220804424100', 'MA010120220804816502', 'MA010120220804731054', 'MA010120220804827764', 'MA010120220804827782', 'MA010120220804815994', 'MA010120220804816000', 'MA010120220805379719', 'MA0106202301A0044421', 'MA0101202308A0035193', 'MA010120220805835205', 'MA010120220806406655', 'MA010120220806523765', 'MA010120220806569410', 'MA010120220806835324', 'MA010120220807404865', 'MA010120220808059277', 'MA010120220808220963', 'MA010120220808188777', 'MA010120220808178039', 'MA010120220808329444', 'MA010120220808321561', 'MA010120220808321383', 'MA010120220808293496', 'MA010120220808430652', 'MA010120220808572196', 'MA010120220808660743', 'MA010120220809135193', 'MA010120220809677529', 'MA010120220810085821', 'MA010120220810309129', 'MA010120220810590397', 'MA010120220811938349', 'MA010120220811898845', 'MA010120220812141259', 'MA010120220812424249', 'MA010120220812495905', 'MA010120220813013639', 'MA010120220813110001', 'MA010120220813236845', 'MA010120220813320650', 'MA010120220813463599', 'MA010120220813812267', 'MA010120220813938424', 'MA010120220813950414', 'MA010120220813913196', 'MA0101202211A0065722', 'MA010120220800131389', 'MA010120220800639599', 'MA010120220800792474', 'MA010120220801257669', 'MA010120220801298030', 'MA010120220801615873', 'MA010120220801928238', 'MA010120220801869152', 'MA010120220802051292', 'MA010120220803277052', 'MA010120220803319237', 'MA010120220803450242', 'MA010120220803458253', 'MA010120220803458586', 'MA010120220803487198', 'MA010120220803474056', 'MA010120220803604767', 'MA010120220803767619', 'MA010120220803893892', 'MA010120220804109462', 'MA010120220804088849', 'MA010120220804266045', 'MA010120220804260626', 'MA010120220804255334', 'MA010120220804252722', 'MA010120220804295093', 'MA010120220804294995', 'MA010120220804426549', 'MA010120220804408990', 'MA010120220804438020', 'MA010120220804815909', 'MA010120220805236146', 'MA0101202305A0066649', 'MA0101202308A0035848', 'MA0101202310A0014466', 'MA010120220805536372', 'MA010120220806839675', 'MA010120220806959942', 'MA010120220806969311', 'MA010120220807431193', 'MA010120220808077717', 'MA010120220808406418', 'MA010120220808542253', 'MA010120220808539571', 'MA010120220809240232', 'MA010120220809291601', 'MA010120220811742159', 'MA010120220811873824', 'MA010120220812074097', 'MA010120220812487004', 'MA010120220812950902', 'MA010120220813010433', 'MA010120220814026987', 'MA010120220814030411', 'MA010120220800356119', 'MA010120220800593337', 'MA010120220800647022', 'MA010120220801050866', 'MA010120220801039196', 'MA010120220800978344', 'MA010120220800960098', 'MA ...

# %%
print(data["상가업소번호"])
# Out:
# 0         MA010120220805430767
# 1         MA010120220805430763
# 2         MA010120220805430969
# 3         MA010120220805431023
# 4         MA010120220805431191
#                   ...
# 489867    MA010120220804254954
# 489868    MA010120220808716142
# 489869    MA010120220806734217
# 489870    MA010120220806779253
# 489871    MA010120220809735562
# Name: 상가업소번호, Length: 489872, dtype: object

# %%
# 원 안에 있는 상가 업소 데이터 가져오기
selected_data = data[data["상가업소번호"].isin(locations_inside_circle)]
selected_cafe_data = selected_data[(selected_data["상권업종소분류명"].isin(["카페", "빵/도넛"]))]
# selected_cafe_data
print(len(selected_cafe_data))
# selected_cafe_data.to_csv('jamsilStation_cafe.csv')
# Out:
# 27

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# 잠실역 중심 지도
map = folium.Map(location=[37.5131, 127.1006], zoom_start=10)

# 원을 그릴 위치의 위도와 경도를 설정
circle_lat_lon = [37.5131, 127.1006]

# folium.Circle() 메소드로 원 생성
folium.Circle(
    location=circle_lat_lon,
    radius=200,  # 원의 반지름 (미터 단위)
    color='crimson',
    fill=True,  # 테두리
    fill_color='crimson'
).add_to(map)

data = pd.read_csv("jamsilStation_cafe.csv")

# MarkerCluster 객체 생성
marker_cluster = MarkerCluster().add_to(map)

# 데이터프레임에서 상가 업소의 위치를 지도에 표시
for index, row in data.iterrows():
    location = (row['위도'], row['경도'])  # 상가 업소의 위도와 경도
    folium.Marker(location).add_to(marker_cluster)  # 마커를 클러스터에 추가

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6fe5fd05a1ab5b18ff9760f41a0cfc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6fe5fd05a1ab5b18ff9760f41a0cfc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6fe5fd05a1ab5b18ff9760f41a0cfc3 = L.map(
#                 &quot;map_b6fe5fd05a1ab5b18ff9760f41a0cfc3&quot;,
#                 {
#                     center: [37.5131, 127.1006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e847f9a3adbbfcc6d69bf4287d8e262e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e847f9a3adbbfcc6d69bf4287d8e262e.addTo(map_b6fe5fd05a1ab5b18ff9760f41a0cfc3);
#
#
#             var circle_c1de3f6800886ad8f237bfe2713db548 = L.circle(
#                 [37.5131, 127.1006],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b6fe5fd05a1ab5b18ff9760f41a0cfc3);
#
#
#             var marker_cluster_fca0c9819d0037a15121d19eb4b6c202 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_554f5ba9f4fe2d4229878328d983ee8e = L.marker(
#                 [37.5116492541803, 127.100801051691],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_5771f320cda7022d1bc894187981b432 = L.marker(
#                 [37.5134502581858, 127.100655016038],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_d0b162a288317225f95d0b57172e7b9d = L.marker(
#                 [37.5143686501931, 127.100564812841],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_d2b4dd0d013bde391f1ae50c850adfb5 = L.marker(
#                 [37.5116492541803, 127.100801051691],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_f67d0e24c7527a964bef397914d698c6 = L.marker(
#                 [37.5134502581858, 127.100655016038],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_5c73bc1c83dfa14822a02bfe21091a29 = L.marker(
#                 [37.5116492541803, 127.100801051691],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_133e8186974d2ef85d8ef0d52f410536 = L.marker(
#                 [37.5134502581858, 127.100655016038],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_9392df8266b39471d240a48823118168 = L.marker(
#                 [37.5143686501931, 127.100564812841],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_36d91e4ee5f16b98d918a64829e9b055 = L.marker(
#                 [37.5138466873742, 127.100650259009],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_e700c1cd8a3a3ad935eebab1e558e4fe = L.marker(
#                 [37.5116492541803, 127.100801051691],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_4997634e342a859a08a17900b7d7507e = L.marker(
#                 [37.5144227087106, 127.100564164074],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_1a028c02b61659c5f7439465739a6752 = L.marker(
#                 [37.5116492541803, 127.100801051691],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);
#
#
#             var marker_3c04214840d0e50c60808a0d08dc08e1 = L.marker(
#                 [37.5116492541803, 127.100801051691],
#                 {}
#             ).addTo(marker_cluster_fca0c9819d0037a15121d19eb4b6c202);

# %%
# 마커 위치에 미세한 변화를 주어 겹치지 X, 불규칙한 분포

import folium
import pandas as pd
import numpy as np

# 잠실역 중심 지도
map = folium.Map(location=[37.5131, 127.1006], zoom_start=10)

# 원을 그릴 위치의 위도와 경도를 설정
circle_lat_lon = [37.5131, 127.1006]

# folium.Circle() 메소드로 원 생성
folium.Circle(
    location=circle_lat_lon,
    radius=200,  # 원의 반지름 (미터 단위)
    color='crimson',
    fill=True,  # 테두리
    fill_color='crimson'
).add_to(map)

data = pd.read_csv("jamsilStation_cafe.csv")
marker_count = 0

# 데이터프레임에서 상가 업소의 위치를 지도에 표시
for index, row in data.iterrows():
    # 상가 업소의 위도와 경도에 미세한 변화 추가 
    location = (row['위도'] + np.random.uniform(-0.00005, 0.00005), row['경도'] + np.random.uniform(-0.00005, 0.00005))
    folium.Marker(location, icon = folium.Icon(icon = 'coffee', prefix = 'fa', color = 'red', icon_size = 35)).add_to(map)  # 개별 마커 추가
    marker_count += 1

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e18e0b9174866c5885d9926e41c6059f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e18e0b9174866c5885d9926e41c6059f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e18e0b9174866c5885d9926e41c6059f = L.map(
#                 &quot;map_e18e0b9174866c5885d9926e41c6059f&quot;,
#                 {
#                     center: [37.5131, 127.1006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bffaeb13342051c1bd85655bf36fd43c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bffaeb13342051c1bd85655bf36fd43c.addTo(map_e18e0b9174866c5885d9926e41c6059f);
#
#
#             var circle_99ddd4815f86865d71c9c15d15ce7822 = L.circle(
#                 [37.5131, 127.1006],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e18e0b9174866c5885d9926e41c6059f);
#
#
#             var marker_5418a9ef0341cc8ef88620c6def68c0b = L.marker(
#                 [37.51168349780087, 127.10083961056158],
#                 {}
#             ).addTo(map_e18e0b9174866c5885d9926e41c6059f);
#
#
#             var icon_abb843115f32c2dcbe74db6ca5949b73 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: 35, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5418a9ef0341cc8ef88620c6def68c0b.setIcon(icon_abb843115f32c2dcbe74db6ca5949b73);
#
#
#             var marker_fabde5308d83fbfd828b2c27d3619eb8 = L.marker(
#                 [37.51340950738791, 127.10066651997525],
#                 {}
#             ).addTo(map_e18e0b9174866c5885d9926e41c6059f);
#
#
#             var icon_9c3ff183a4bee738ec443fbc516cb772 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: 35, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fabde5308d83fbfd828b2c27d3619eb8.setIcon(icon_9c3ff183a4bee738ec443fbc516cb772);
#
#
#             var marker_da430f969e3b21092e85bce00c8511ff = L.marker(
#                 [37.51441855301489, 127.10058684390846],
#                 {}
#             ).addTo(map_e18e0b9174866c5885d9926e41c6059f);
#
#
#             var icon_40444aff143aeb7743ec0aa45f0ae3ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: 35, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_da430f969e3b21092e85bce00c8511ff.setIcon(icon_40444aff143aeb7743ec0aa45f0ae3ed);
#
#
#             var marker_0c64f6b41c8a8e579fc538cd4f9d4f96 = L.marker(
#                 [37.51168336077451, 127.10079384369206],
#                 {}
#             ).addTo(map_e18e0b9174866c5885d9926e41c6059f);
#
#
#             var icon_685abe3aa1e2023e27fa16742c66b8a4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: 35, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0c64f6b41c8a8e579fc538cd4f9d4f96.setIcon(icon_685abe3aa1e2023e27fa16742c66b8a4);
#
#
#             var marker_0ff250321a6bab83e9194f5a3bd91c1c = L.marker(
#                 [37.51344732493428, 127.1006244934622],
#                 {}
#             ).addTo(map_e18e0b9174866c5885d9926e41c6059f);
#
#
#             var icon_4ae3b4bb4eece36ace1527e5765366b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: 35, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0ff250321a6bab83e9194f5a3bd91c1c.setIcon(icon_4ae3b4bb4eece36ace1527e5765366b1);
#
#
#             var marker_c49be5fb26b31a825b6d11227de04938 = L.marker(
#                 [37.511686500063455, 127.1008264

# %%
marker_count_df = pd.DataFrame({"Count": [marker_count]}, index = ['잠실역 200m 반경 내 카페'])
marker_count_df
# Out:
#                   Count
# 잠실역 200m 반경 내 카페     27
